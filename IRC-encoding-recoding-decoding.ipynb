# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
# %run -i ./NNagent_IRCfromFile-01262020(170602).ipynb
# Out:
# findfont: Font family ['CMU Serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['CMU Serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['CMU Serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['CMU Serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['CMU Serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['CMU Serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['CMU Serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['CMU Serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['CMU Serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['CMU Serif'] not found. Falling back to DejaVu Sans.
# <ipython-input-1-d731bbdf8170>:11: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.title('Absolute value of Hessian eigenvalues', fontsIZE = 20)
# findfont: Font family ['CMU Serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['CMU Serif'] not found. Falling back to DejaVu Sans.
# Set the parameters of the model...
#
# Generating data...
# <ipython-input-1-6b101ef89cce>:18: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0, 0].set_xticklabels(labels, rotation=60, ha = 'center', fontsize = 20)
# 0.9999999999998981 0.9999999999998981 0.9999999999998981
# 0.9999999999998981 0.9999999999998981 0.9999999999998981
# [[0.4040497  0.31293143 0.14588127 0.05844455 0.04601933 0.01978831
#   0.00736309]
#  [0.36018307 0.35286041 0.16933638 0.07002288 0.02974828 0.00915332
#   0.00503432]
#  [0.42921625 0.34140336 0.12802626 0.05416496 0.02749282 0.0131309
#   0.00369307]]
# 0.9944776806258391 0.9944776806258391 0.9944776806258391
# [[0.49486191 0.23619139 0.11335902 0.05266538 0.03676943 0.02360308
#   0.01332691]
#  [0.41355216 0.28501787 0.14965876 0.06191095 0.0401365  0.02177446
#   0.01283718]
#  [0.42777689 0.29667885 0.12633084 0.05990783 0.042587   0.01954553
#   0.01001112]]
# 0.9707771355171055 0.9707771355171055 0.9707771355171055
# <ipython-input-1-48057fa947ad>:26: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0, 0].set_xticklabels(labels, rotation=60, ha = 'center', fontsize = 20)
# data preprocessing is successfully done!

# %%
# %run -i ./neural_encoding.ipynb
# Out:
# score [0.94608301 0.96457961]
# score [0.94201266 0.96722637]
# score [0.94607093 0.96557515]
# score [0.94824061 0.96338913]
# score [0.94561986 0.96754768]
# score [0.94880532 0.96214191]
# score [0.94492775 0.96304464]
# score [0.94885958 0.96385154]
# score [0.94269628 0.96338227]
# score [0.95023639 0.96489511]
# Intercept:  [0.04252245 0.37151997]
# Coef:  [[-7.10894774e-01  1.80014087e-01  8.67392942e-02  8.24589495e-02
#   -1.97585906e-02  1.34242341e-01  8.08289051e-02  3.60408298e-02
#    6.80411125e-02 -2.99518361e-01  3.57183149e-01  5.91755728e-01
#    3.51619385e-02 -1.88468720e-01 -1.05184748e-03  1.24487442e-01
#    1.64521117e-01 -3.33394680e-04  5.42306023e-01 -2.49552927e-01
#   -7.91556678e-03 -2.56734222e-01 -3.66063213e-01  9.23201365e-02
#   -5.41192076e-02  6.19456396e-01 -6.33166021e-02 -1.57728059e-02
#   -2.17444028e-02 -1.31404173e-02 -3.38488361e-01  2.29909137e-01
#   -2.19703357e-01  2.72390912e-02 -9.43794571e-02 -1.05265795e-02
#   -4.35298629e-01  1.05205623e-01  5.96387868e-01 -7.97843842e-01
#    8.53571083e-02  3.84108159e-02 -1.00257472e-01 -2.17581922e-01
#   -3.25153337e-01  1.45850831e-01  7.06876559e-01  2.97618710e-01
#   -2.41092661e-01 -3.05671446e-01  7.64095747e-02 -5.55683132e-01
#   -2.75030282e-02 -4.50207439e-03 -2.47223731e-01  6.43726194e-02
#   -2.05397709e-03  4.12364805e-01  2.95579993e-01 -1.85405903e-01
#    6.39302417e-03 -4.45319972e-02 -5.91297975e-02  5.25005783e-01
#   -2.20399885e-01 -2.63977637e-01 -3.24399355e-01 -7.77912909e-02
#    6.11660223e-02 -6.30362668e-02 -1.15741599e-01 -1.26747165e-01
#   -2.17062561e-01 -4.67818011e-01 -2.06639513e-01  1.02527460e-01
#   -3.23394680e-01 -3.40449045e-01  1.10618416e-01 -3.61877586e-01
#   -1.93772480e-01 -2.11515823e-02  6.58867242e-02  3.57308975e-01
#   -1.02691672e-01 -2.02543250e-02  2.68825453e-01  3.11654171e-01
#    3.29197803e-02 -3.45586207e-02 -6.94751373e-02 -1.50685463e-01
#    4.88909581e-02 -2.88696366e-01 -1.36336583e-01  1.49688445e-01
#    3.38065937e-02  1.84933707e-01  2.86282803e-01  1.44475504e-01]
#  [ 2.01022963e-01  3.23040125e-01 -3.63168383e-01 -3.71893558e-01
#   -2.36302606e-01  8.81555530e-02  9.53022990e-02  4.25174057e-01
#   -2.00786170e-02  1.11944553e-01  1.06529107e-01 -2.39780222e-01
#   -2.33163926e-02 -3.54632268e-01  2.25719906e-01 -2.42444319e-01
#    5.42556977e-02 -1.13562990e-01  1.47800295e-01 -4.29082792e-01
#    5.37453973e-01 -1.00103860e-01 -3.81203383e-02  1.12177089e-01
#    6.75578746e-01  8.30741264e-02  2.74486426e-01 -3.43429017e-02
#    9.65401353e-02  2.20998023e-01 -2.21151850e-01 -5.76648344e-01
#    2.59344268e-01  5.06439948e-01  6.09280610e-02 -1.25742367e-01
#   -2.36499929e-01  1.01077334e-01 -1.88388199e-01  2.47330786e-01
#    1.60552354e-01  2.98038155e-01  4.75480024e-01  3.59654885e-01
#   -3.09245971e-01 -1.03277474e+00  1.12670194e-01 -1.21049965e-01
#   -1.05477455e-01 -2.71090954e-01 -4.28814351e-01  9.29391676e-02
#   -4.60224760e-01  1.32884034e-01  2.50030647e-01 -1.18024544e-01
#    2.33499218e-01 -1.36707159e-01  2.47379237e-01 -2.82571135e-01
#   -2.08870320e-02  7.26895171e-02 -4.14816947e-02  2.82488729e-01
#   -2.74811660e-01  2.65100063e-01 -5.24235415e-01  4.42804569e-01
#    8.82892688e-02 -1.25439194e-01  2.11672968e-01 -1.48624366e-02
#    2.60163228e-01  5.63232813e-02 -1.96588364e-01  7.91545169e-02
#   -3.26025841e-01 -3.87818296e-02 -1.28879174e-01 -2.87604153e-01
#    4.01581635e-02  3.97069161e-01 -4.17500984e-01 -1.98134858e-01
#    9.20015632e-02 -5.31303159e-02 -8.28636444e-02  5.17504808e-02
#    7.28460786e-02 -3.08416381e-01 -1.86465487e-02  2.89898117e-01
#   -2.12141067e-01 -1.34801389e-01  3.85778080e-03  4.66655883e-01
#   -4.08244456e-01 -2.84858439e-01  4.67129281e-01  3.26651982e-01]]
# encoding mean squared error:
#  behavior_belief1    0.002735
# behavior_belief2    0.002674
# dtype: float64
# encoding error std:
#  behavior_belief1    0.052291
# behavior_belief2    0.051710
# dtype: float64
# score [0.94549448 0.96596509]
# findfont: Font family ['CMU Serif'] not found. Falling back to DejaVu Sans.

# %%
# %run -i ./neural_recoding_KRR.ipynb
# Out:
# score [0.69999545 0.80988487]
# score [0.69371719 0.80822433]
# Mean squared error:
#  [0.01330771 0.01374135]
# squared error std:
#  [0.01755267 0.0176498 ]
# score [0.71842482 0.81777305]
# score [0.68984174 0.79711955]
# score [0.68327304 0.7958195 ]
# Mean squared error:
#  [0.01489304 0.01501121]
# squared error std:
#  [0.02073934 0.02195573]
# score [0.69821728 0.80640847]
# action 0 color 0 0.8988277729538022
# action 0 color 1 0.9334564520765652
# action 0 color 2 0.9392093443236181
# action 0 color 3 0.9031794372929737
# action 0 color 4 0.9097377488416886
# action 1 color 0 0.8896831441411133
# action 1 color 1 0.921466446055297
# action 1 color 2 0.9229492350874878
# action 1 color 3 0.9048398365537134
# action 1 color 4 0.8564722309300832
# action 2 color 0 0.9415291668899095
# action 2 color 1 0.9416477267217145
# action 2 color 2 0.9166755787075703
# action 2 color 3 0.8837032034680936
# action 2 color 4 0.7498441763359497
# action 3 color 0 0.8438257475914226
# action 3 color 1 0.9292889975298742
# action 3 color 2 0.948406637687959
# action 3 color 3 0.945523343753483
# action 3 color 4 0.9312187833488126
# action 4 color 0 0.99518647920472
# action 4 color 1 0.9938352441169204
# action 4 color 2 0.9925085982883901
# action 4 color 3 0.9913403737150636
# action 4 color 4 0.9881856094042106

# %%
# %run -i ./neural_decoding_LR.ipynb
# Out:
# Using RBF nonlinearity.
